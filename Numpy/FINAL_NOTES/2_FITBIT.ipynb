# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
#### Have you seen something like this ? 

from IPython.display import Image

# Provide the path to the image file (can be a URL as well)
Image('D:\\PROJECT_PRACTISE_DIRS\\DSML_PRACTISE_FILES\\STATISTICS\\images\\data-screenshot.png')

# %%
data = np.loadtxt('D:\\utils\\DataSets\\Scalar\\fit.txt', dtype ='str')
data[0:2]
# Out:
# array([['06-10-2017', '5464', 'Neutral', '181', '5', 'Inactive'],
#        ['07-10-2017', '6041', 'Sad', '197', '8', 'Inactive']],
#       dtype='<U10')

# %%
date, step_count, mood, calories_burned, hours_of_sleep, activity_status = data.T

# %%
step_count = np.array(step_count, dtype = 'int')
step_count.dtype
# Out:
# dtype('int32')

# %%
calories_burned = np.array(calories_burned, dtype = 'int')
calories_burned.dtype
# Out:
# dtype('int32')

# %%
hours_of_sleep = np.array(hours_of_sleep, dtype = 'int')
hours_of_sleep.dtype
# Out:
# dtype('int32')

# %%
np.unique(mood)
# Out:
# array(['Happy', 'Neutral', 'Sad'], dtype='<U10')

# %%
np.unique(activity_status)
# Out:
# array(['Active', 'Inactive'], dtype='<U10')

# %%
#How many active and inactive records are there in the dataset?
print(np.unique(activity_status[activity_status == 'Active'], return_counts = True))
print(np.unique(activity_status[activity_status == 'Inactive'], return_counts = True))
# Out:
# (array(['Active'], dtype='<U10'), array([42], dtype=int64))
# (array(['Inactive'], dtype='<U10'), array([54], dtype=int64))

# %%
print(np.mean(step_count[activity_status == 'Active']))
print(np.max(step_count[activity_status == 'Active']))
print(np.min(step_count[activity_status == 'Active']))
# Out:
# 3226.5714285714284
# 7422
# 221

# %%
print(np.mean(step_count[activity_status == 'Inactive']))
print(np.max(step_count[activity_status == 'Inactive']))
print(np.min(step_count[activity_status == 'Inactive']))
# Out:
# 2709.8888888888887
# 6930
# 25

# %%
np.mean(step_count[mood == 'Happy'])
# Out:
# 3392.725

# %%
np.mean(step_count[mood == 'Sad'])
# Out:
# 2103.0689655172414

# %%
# In Which Date Max Steps were recorded?
max_steps = date[np.argmax(step_count)]
print(max_steps,step_count[np.argmax(step_count)])
# In Which Date Min Steps were recorded?  
min_steps = date[np.argmin(step_count)]
print(min_steps,step_count[np.argmin(step_count)])
# Out:
# 14-12-2017 7422
# 08-10-2017 25

# %%
print(np.unique(mood[hours_of_sleep >5], return_counts = True))
# Out:
# (array(['Happy', 'Neutral', 'Sad'], dtype='<U10'), array([20,  3, 10], dtype=int64))

# %%
print(np.unique(mood[hours_of_sleep <5], return_counts = True))
# Out:
# (array(['Happy', 'Neutral', 'Sad'], dtype='<U10'), array([ 7,  9, 10], dtype=int64))

# %%
print(np.unique(mood[step_count <=2000], return_counts = True))
# Out:
# (array(['Happy', 'Neutral', 'Sad'], dtype='<U10'), array([13,  8, 18], dtype=int64))

# %%
print(np.unique(mood[step_count >=3000], return_counts = True))
# Out:
# (array(['Happy', 'Neutral', 'Sad'], dtype='<U10'), array([24, 14, 10], dtype=int64))
